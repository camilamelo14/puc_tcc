# %% [markdown]
# ## Definição do Tema
#
# Neste link podemos avaliar em modo geral os dados já coletados ref. a suicídio (ambos sexos): http://apps.who.int/gho/data/node.sdg.3-4-viz-2?lang=en
#
# Falando por suicpidio a cada 1000.000 habitantes temos alguns índices:
#
# - ##### Top 10 maiores indices:
#
#
#     - Lithuania (31.9) -> M (58.1) F (9.5)
#     - Russia (31) -> M (55.9) F (9.4)
#          - Gyyana (29.2) -> M (43.7) F (14.4) *
#          - Republic of Korea (26.9) -> M (38.4) F (15.4)*
#     - Belarus (26.2) -> M (46.9) F (8.2)
#          - Suriname (22.8) -> M (10.9) F (34.7) *
#     - Kazakstan (22.5) -> M (38.3) F (7.6)
#     - Ukraine (22.4) -> M (41.1) F (6.3)
#          - Usatho (21.2) -> M (17.8) F (24.4)*
#     - Japan (18.5) -> M (26) F (11.4)
#
# Neste link fala um pouco sobre Suriname, porém o gráfico apresentado neste link não condiz com o valor apresentado nos dados do WHO: https://apps.who.int/iris/bitstream/handle/10665/168802/ccs_sur_en.pdf?sequence=1
#
# O que me leva a crer que o ideal seria utlizarmos países com dados de referência em nosso trabalho desta forma teremos uma acertividade melhor e uma análise mais acertiva e sem outliers enganosos (como no exemplo acima).
#
# ![\img\001.png](attachment:image.png)
#
# https://www.iccp-portal.org/sites/default/files/plans/national_action_plan_for_the_prevention_and_control_of_noncommunicable_diseases_2012-2016.pdf

# %% [markdown]
# https://gateway.euro.who.int/en/datasets/european-health-for-all-database/
#
# ![img\002.png](attachment:image.png)

# %% [markdown]
# https://gateway.euro.who.int/en/datasets/enhis/
#
# ![img\003.png](attachment:image.png)

# %% [markdown]
# https://gateway.euro.who.int/en/hfa-explorer/
#
# ![img\004.png](attachment:image.png)

# %% [markdown]
# https://stats.oecd.org/index.aspx?DataSetCode=HEALTH_STAT
#
# https://www.oecd.org/health/health-data.htm
#
# ![img\005.png](attachment:image.png)

# %% [markdown]
# https://www.paho.org/bra/index.php?option=com_content&view=article&id=5676:organizacao-mundial-da-saude-divulga-novas-estatisticas-mundiais-de-saude&Itemid=843
#
# ![img\006.png](attachment:image.png)

# %% [markdown]
# ## Links
#
# https://www.prevencaosuicidio.blog.br/dados
#
# https://www.afro.who.int/health-topics/mental-health
#
# mhGAP operations manual: https://apps.who.int/iris/bitstream/handle/10665/275386/9789241514811-eng.pdf?ua=1
# https://www.who.int/mental_health/action_plan_2013/mhap_brochure.pdf?ua=1
#
# Mental Health ATLAS 2017 Member State Profile: https://www.who.int/mental_health/evidence/atlas/profiles-2017/BRA.pdf?ua=1
#
# Global Health Observatory - Map Gallery: http://gamapserver.who.int/mapLibrary/app/searchResults.aspx
#
#
# Data tables - Country data: http://apps.who.int/gho/data/view.sdg.3-4-data-ctry?lang=en
#
# JSON data: https://apps.who.int/gho/athena/data/GHO/NCDMORT3070,SDGSUICIDE.json?filter=COUNTRY:*;AGEGROUP:-

# %% [markdown]
# ### Ref. a dados confiáveis:
#
# https://www.who.int/bulletin/volumes/88/6/09-074393/en/
#
# https://www.who.int/healthinfo/paper28.pdf
#
# ![img\007.png](attachment:image.png)

# %% [markdown]
# ### Pesquisas levantadas pela Cris
#
# Dataset da who:
# http://apps.who.int/healthinfo/statistics/mortality/whodpms/params_ex.php
#
# Pagina da who com pesquisas consolidadas:
# https://www.who.int/mental_health/suicide-prevention/en/
#
# podiamos usar este acordo q mostra o desejo de diminuir o indice em 10% ate 2020:
# https://www.who.int/mental_health/mhgap/en/
#
# relatorio da reuters de 2017 com os paises que tem pesquisa de referencia em suicidio, inclusive seus proprios reports pela reuters:
# http://www.digitalnewsreport.org/survey/2017/resources-2017
#
# Mental health action plan 2013 - 2020:
# https://www.who.int/mental_health/publications/action_plan/en/
#
# - Austria
# - Australia
# - Alemanha
# - Dinamarca
# - Finandia
# - Coreia do Sul
# - Irlanda
# - Espanha
# - Noruega
#
#
# Costs of Suicide
# https://www.sprc.org/about-suicide/costs
#
# Olha que interessante este framework
# https://www.canada.ca/en/public-health/services/publications/healthy-living/suicide-prevention-framework.html

# %% [markdown]
# Quality of suicide mortality data: https://www.who.int/mental_health/suicide-prevention/mortality_data_quality/en/
#
# Com base no indicativo acima e mais o dataSet (http://apps.who.int/gho/data/view.sdg.3-4-data-ctry?lang=en) fiz um levantamento no seguinte arquivo: \data\Levantamento_Inicial.xlsx
#
# Dados de 2019: http://worldpopulationreview.com/countries/suicide-rate-by-country/#suicideRate (Dados quase idênticos ao de 2016)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Temos alguns indicadores:
#
# - ### Indices que diminuíram entre 2015 e 2016
#     - Lithuania 43,9 para 31,9
#     - Rússia 51,6 para 31
#     - Belarus 45,1 para 26,2
#     - Kazaksthan 39,4 para 22,5
#     - Ukraine 34,5 para 22,4
#
# - ### Indices que aumentaram entre 2015 e 2016
#     - Guyana (Medium quality) 24,4 para 29,2
#     - Uruguay 15,3 para 18,4
#     - United States 11,9 para 15,3
#     - Portugual 11,1 para 14
#     - Netherlands 9,9 para 12,6
#     - Canada 10,1 para 12,5
#
# Acredito que podemos explorar as seguintes situações:
#
# 1. Piores índices com diminuição (caso da Rússia)
# 2. Piores índices com aumento (caso da United States)
# 3. Pirores índices (com diminuição do índice, mas com aumento de mulheres)
# 4. Pirores índices (com aumento do índice, mas com aumento sig. entre mulheres)
#
#
# 5. Melhores Índices com diminuição significativa (Avaliar o motivo da diminuição)
# 6. Índice baixo, mas com aumento significativo, ou seja, acima da média mundial ou do país
#
#
# 7. País com maior número de suicídios entre idosos
# 8. País com maior número de suicídios entre adultos
# 9. País com maior número de suicídios entre jovens
#
#
# 10. Formas mais comuns de cometer suicídio (considerar todos os países que escolhermos)
# 11. Avaliar o clima nos locais com maiores números (Se tiver a data da ocorrência avaliar a estação do ano ou a temperatura do local naquela data)
# 12. Avaliar se possível as tentativas de suicídio (Se este número é maior entre as mulheres do que nos homens, como aqui no Brasil)
#
#
# 13. Avaliar estados individuais, exemplo no Brasil Rio Grande do Sul tem um rate de 10, no sul por exemplo tem a concentração dos números, Mérida na Venezuela em 2015 apresentou um rate de 12/100k habitantes (Número alto)
